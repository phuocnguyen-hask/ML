# %%
from sklearn.datasets import load_iris
from sklearn.tree import DecisionTreeClassifier
from mlxtend.plotting import plot_decision_regions
import matplotlib.pyplot as plt

iris = load_iris()
X = iris.data[:, 2:]
y = iris.target

tree_clf = DecisionTreeClassifier(max_depth = 2)
tree_clf.fit(X, y)

plot_decision_regions(X, y, clf = tree_clf, legend = 2)
plt.xlabel('petal length')
plt.ylabel('petal width')
plt.legend()
plt.show()

# %%
from sklearn.tree import export_graphviz
export_graphviz(tree_clf,
                out_file = 'images/tree.dot',
                feature_names = iris.feature_names[2:],
                class_names = iris.target_names,
                rounded = True,
                filled = True)

# %%
tree_clf.predict_proba([[5, 1.5]])
# Out:
# array([[0.        , 0.90740741, 0.09259259]])

# %%
import numpy as np
X = np.random.rand(100, 1) * 4 - 3
y = (2.1 * X ** 2 + 0.3 * X + 1 + np.random.standard_normal(100).reshape(-1,1)).reshape(-1,)

# %%
from sklearn.tree import DecisionTreeRegressor
tree_reg = DecisionTreeRegressor(max_depth = 2)
tree_reg.fit(X, y)
# Out:
# DecisionTreeRegressor(max_depth=2)

# %%
x_draw = np.linspace(-4, 2, 100).reshape(-1, 1)
y_draw_pred = tree_reg.predict(x_draw)
plt.scatter(X, y, label = 'data')
plt.plot(x_draw, y_draw_pred, color = 'red', label = 'tree regressor')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.show()
